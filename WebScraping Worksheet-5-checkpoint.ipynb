# %%
#answer-1

from urllib.request import urlopen
from bs4 import BeautifulSoup
url = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(url, "html.parser")
headers = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('header tags :', *headers, sep='\n\n')
# Out:
# header tags :
#
# <h1 class="firstHeading" id="firstHeading" lang="en">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
#
# <h2>Navigation menu</h2>
#
# <h3 id="p-personal-label">
# <span>Personal tools</span>
# </h3>
#
# <h3 id="p-namespaces-label">
# <span>Namespaces</span>
# </h3>
#
# <h3 id="p-variants-label">
# <span>Variants</span>
# </h3>
#
# <h3 id="p-views-label">
# <span>Views</span>
# </h3>
#
# <h3 id="p-cactions-label">
# <span>More</span>
# </h3>
#
# <h3>
# <label for="searchInput">Search</label>
# </h3>
#
# <h3 id="p-navigation-label">
# <span>Navigation</span>
# </h3>
#
# <h3 id="p-interaction-label">
# <span>Contribute</span>
# </h3>
#
# <h3 id="p-tb-label">
# <span>Tools</span>
# </h3>
#
# <h3 id="p-coll-print_export-label">
# <span>Print/export</span>
# </h3>
#
# <h3 id="p-wikibase-otherprojects-label">
# <span>In other projects</span>
# </h3>
#
# <h3 id="p-lang-label">
# <span>Languages</span>
# </h3>

# %%
#answer-2

from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
# Download IMDB's Top 250 data
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]
imdb_rating= [b.attrs.get('data-value') for b in soup.select('td.strong.text')]
imdb = []

for index in range(0, 100):
   
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    irating=imdb_rating
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating":ratings[index],
            "vote": votes[index],
            "link": links[index],
           "imdb_rating":irating}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'],item["rating"])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman 9.222789550169752
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino 9.148681628349179
# 3 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro 8.98094897618684
# 4 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger 8.973516034987227
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb 8.93083351297781
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes 8.907585324010142
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen 8.883742237636245
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman 8.845029330630299
# 9 - Il buono, il brutto, il cattivo (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach 8.79608186701174
# 1 -  The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen 8.775343039225014
# 11 - Fight Club (1999) - Starring: David Fincher (dir.), Brad Pitt, Edward Norton 8.766273150116426
# 12 - Forrest Gump (1994) - Starring: Robert Zemeckis (dir.), Tom Hanks, Robin Wright 8.753164743574507
# 13 - Inception (2010) - Starring: Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt 8.721049467885177
# 14 - The Lord of the Rings: The Two Towers (2002) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen 8.698761916761109
# 15 - Star Wars: Episode V - The Empire Strikes Back (1980) - Starring: Irvin Kershner (dir.), Mark Hamill, Harrison Ford 8.69819927341573
# 16 - The Matrix (1999) - Starring: Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne 8.648630424239965
# 17 - Goodfellas (1990) - Starring: Martin Scorsese (dir.), Robert De Niro, Ray Liotta 8.643284369081785
# 18 - One Flew Over the Cuckoo's Nest (1975) - Starring: Milos Forman (dir.), Jack Nicholson, Louise Fletcher 8.63862006181783
# 19 - Shichinin no samurai (1954) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura 8.603998606129164
# 20 - Se7en (1995) - Starring: David Fincher (dir.), Morgan Freeman, Brad Pitt 8.591985604365721
# 21 - La vita è bella (1997) - Starring: Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi 8.582828330117657
# 22 - Cidade de Deus (2002) - Starring: Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino 8.580002407342386
# 23 - The Silence of the Lambs (1991) - Starring: Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins 8.575481820461984
# 24 - It's a Wonderful Life (1946) - Starring: Frank Capra (dir.), James Stewart, Donna Reed 8.571217190784221
# 25 - Star Wars (1977) - Starring: George Lucas (dir.), Mark Hamill, Harrison Ford 8.555704952616907
# 26 - Saving Private Ryan (1998) - Starring: Steven Spielberg (dir.), Tom Hanks, Matt Damon 8.549409929134457
# 27 - Sen to Chihiro no kamikakushi (2001) - Starring: Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette 8.540561063364388
# 28 - The Green Mile (1999) - Starring: Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan 8.538129071256133
# 29 - Gisaengchung (2019) - Starring: Bong Joon Ho (dir.), Kang-ho Song, Sun-kyun Lee 8.532824519423007
# 30 - Interstellar (2014) - Starring: Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway 8.532024909754496
# 31 - Léon (1994) - Starring: Luc Besson (dir.), Jean Reno, Gary Oldman 8.51061001366858
# 32 - The Usual Suspects (1995) - Starring: Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne 8.498766202123123
# 33 - Seppuku (1962) - Starring: Masaki Kobayashi (dir.), Tatsuya Nakadai, Akira Ishihama 8.497280470612745
# 34 - The Lion King (1994) - Starring: Roger Allers (dir.), Matthew Broderick, Jeremy Irons 8.491857721742603
# 35 - Back to the Future (1985) - Starring: Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd 8.486933720043437
# 36 - The Pianist (2002) - Starring: Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann 8.486676672262249
# 37 - Terminator 2: Judgment Day (1991) - Starring: James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton 8.4860411680191
# 38 - American History X (1998) - Starring: Tony Kaye (dir.), Edward Norton, Edward Furlong 8.483519665670837
# 39 - Modern Times (1936) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard 8.482900521923051
# 40 - Psycho (1960) - Starring: Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh 8.477349862397364
# 41 - Gladiator (2000) - Starring: Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix 8.476434287886294
# 42 - City Lights (1931) - Starring: Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill 8.472623963391685
# 43 - The Departed (2006) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon 8.471745431483496
# 44 - Hamilton (2020) - Starring: Thomas Kail (dir.), Lin-Manuel Miranda, Phillipa Soo 8.46980125185973
# 45 - The Intouchables (2011) - Starring: Olivier Nakache (dir.), François Cluzet, Omar Sy 8.468869826100152
# 46 - Whiplash (2014) - Starring: Damien Chazelle (dir.), Miles Teller, J.K. Simmons 8.468237696155917
# 47 - The Prestige (2006) - Starring: Christopher Nolan (dir.), Christian Bale, Hugh Jackman 8.459825987485901
# 48 - Hotaru no haka (1988) - Starring: Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi 8.456627411089032
# 49 - Once Upon a Time in the West (1968) - Starring: Sergio Leone (dir.), Henry Fonda, Charles Bronson 8.448808400845223
# 50 - Casablanca (1942) - Starring: Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman 8.438107170695925
# 51 - Nuovo Cinema Paradiso (1988) - Starring: Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale 8.431037329021125
# 52 - Rear Window (1954) - Starring: Alfred Hitchcock (dir.), James Stewart, Grace Kelly 8.427488706054945
# 53 - Alien (1979) - Starring: Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt 8.421628824493927
# 54 - Apocalypse Now (1979) - Starring: Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando 8.41932521458828
# 55 - Memento (2000) - Starring: Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss 8.414446105837865
# 56 - Raiders of the Lost Ark (1981) - Starring: Steven Spielberg (dir.), Harrison Ford, Karen Allen 8.41020771762402
# 57 - The Great Dictator (1940) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard 8.409893971016029
# 58 - Django Unchained (2012) - Starring: Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz 8.391389145936104
# 59 - The Lives of Others (2006) - Starring: Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck 8.390103702648506
# 60 - Joker (2019) - Starring: Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro 8.389139670882734
# 61 - Paths of Glory (1957) - Starring: Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker 8.375859490756698
# 62 - WALL·E (2008) - Starring: Andrew Stanton (dir.), Ben Burtt, Elissa Knight 8.368780011110504
# 63 - The Shining (1980) - Starring: Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall 8.368182479743563
# 64 - Avengers: Infinity War (2018) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth 8.365243776091091
# 65 - Sunset Blvd (1950) - Starring: Billy Wilder (dir.), William Holden, Gloria Swanson 8.360348564089678
# 66 - Witness for the Prosecution (1957) - Starring: Billy Wilder (dir.), Tyrone Power, Marlene Dietrich 8.353191709982765
# 67 - Spider-Man: Into the Spider-Verse (2018) - Starring: Bob Persichetti (dir.), Shameik Moore, Jake Johnson 8.351412155200132
# 68 - Oldeuboi (2003) - Starring: Chan-wook Park (dir.), Min-sik Choi, Ji-Tae Yoo 8.351247358752673
# 69 - Mononoke-hime (1997) - Starring: Hayao Miyazaki (dir.), Yôji Matsuda, Yuriko Ishida 8.351118076823456
# 70 - Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) - Starring: Stanley Kubrick (dir.), Peter Sellers, George C. Scott 8.350069156843228
# 71 - The Dark Knight Rises (2012) - Starring: Christopher Nolan (dir.), Christian Bale, Tom Hardy 8.33295704977964
# 72 - Once Upon a Time in America (1984) - Starring: Sergio Leone (dir.), Robert De Niro, James Woods 8.33154071588435
# 73 - Aliens (1986) - Starring: James Cameron (dir.), Sigourney Weaver, Michael Biehn 8.323710315248011
# 74 - Kimi no na wa (2016) - Starring: Makoto Shinkai (dir.), Ryûnosuke Kamiki, Mone Kamishiraishi 8.320273582627804
# 75 - Avengers: Endgame (2019) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Evans 8.319684339220426
# 76 - Coco (2017) - Starring: Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal 8.314515701338378
# 77 - American Beauty (1999) - Starring: Sam Mendes (dir.), Kevin Spacey, Annette Bening 8.307000538313385
# 78 - Braveheart (1995) - Starring: Mel Gibson (dir.), Mel Gibson, Sophie Marceau 8.302607383144876
# 79 - 3 Idiots (2009) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Madhavan 8.299805961441429
# 80 - Das Boot (1981) - Starring: Wolfgang Petersen (dir.), Jürgen Prochnow, Herbert Grönemeyer 8.299126729391743
# 81 - Toy Story (1995) - Starring: John Lasseter (dir.), Tom Hanks, Tim Allen 8.29660361501235
# 82 - Tengoku to jigoku (1963) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Yutaka Sada 8.292422868965382
# 83 - Amadeus (1984) - Starring: Milos Forman (dir.), F. Murray Abraham, Tom Hulce 8.29019312715176
# 84 - Capharnaüm (2018) - Starring: Nadine Labaki (dir.), Zain Al Rafeea, Yordanos Shiferaw 8.28748580670851
# 85 - Taare Zameen Par (2007) - Starring: Aamir Khan (dir.), Darsheel Safary, Aamir Khan 8.286080938240712
# 86 - Star Wars: Episode VI - Return of the Jedi (1983) - Starring: Richard Marquand (dir.), Mark Hamill, Harrison Ford 8.28529376446443
# 87 - Inglourious Basterds (2009) - Starring: Quentin Tarantino (dir.), Brad Pitt, Diane Kruger 8.285175062524155
# 88 - Reservoir Dogs (1992) - Starring: Quentin Tarantino (dir.), Harvey Keitel, Tim Roth 8.281153801067926
# 89 - Good Will Hunting (1997) - Starring: Gus Van Sant (dir.), Robin Williams, Matt Damon 8.280733348627457
# 90 - 2001: A Space Odyssey (1968) - Starring: Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood 8.271108873966341
# 91 - Requiem for a Dream (2000) - Starring: Darren Aronofsky (dir.), Ellen Burstyn, Jared Leto 8.267061339393557
# 92 - Vertigo (1958) - Starring: Alfred Hitchcock (dir.), James Stewart, Kim Novak 8.264542021383592
# 93 - M - Eine Stadt sucht einen Mörder (1931) - Starring: Fritz Lang (dir.), Peter Lorre, Ellen Widmann 8.263416900844442
# 94 - Dangal (2016) - Starring: Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar 8.25950561708362
# 95 - Eternal Sunshine of the Spotless Mind (2004) - Starring: Michel Gondry (dir.), Jim Carrey, Kate Winslet 8.259474932231724
# 96 - Jagten (2012) - Starring: Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen 8.258032426540613
# 97 - Citizen Kane (1941) - Starring: Orson Welles (dir.), Orson Welles, Joseph Cotten 8.254950825356836
# 98 - 1917 (2019) - Starring: Sam Mendes (dir.), Dean-Charles Chapman, George MacKay 8.25332941514544
# 99 - Full Metal Jacket (1987) - Starring: Stanley Kubrick (dir.), Matthew Modine, R. Lee Ermey 8.24871028534428
# 10 -  Ladri di biciclette (1948) - Starring: Vittorio De Sica (dir.), Lamberto Maggiorani, Enzo Staiola 8.24751016537966

# %%
#answer-5

import urllib
import requests

from bs4 import BeautifulSoup

def getranking(url):   

#Query the website and return the html to variable 'page'
    page= requests.get(url)


    soup = BeautifulSoup(page.text, 'lxml')

    table = soup.find('table',{'class':'table'})


    A,B=[],[]

    for row in table.findAll('tr'):
 
        cells = row.findAll('td')
        if len(cells) == 5:
     
            
            B.append(cells[1].text.strip())
        
              
    import pandas as pd
    from collections import OrderedDict

    teamorplayer_ranking = ["Team/player"]

    ranking_data = OrderedDict(zip(teamorplayer_ranking,[B]))

    data = pd.DataFrame(ranking_data) 
    data=data[0:10]
    print(data)
url="https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
url2="https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
url3="https://www.icc-cricket.com/rankings/mens/player-rankings/test/bowling"
print(getranking(url))
print(getranking(url2))
print(getranking(url3))
# Out:
#         Team/player
# 0      England\nENG
# 1        India\nIND
# 2   New Zealand\nNZ
# 3    Australia\nAUS
# 4  South Africa\nSA
# 5     Pakistan\nPAK
# 6   Bangladesh\nBAN
# 7     Sri Lanka\nSL
# 8   West Indies\nWI
# 9  Afghanistan\nAFG
# None
#            Team/player
# 0          Virat Kohli
# 1         Rohit Sharma
# 2           Babar Azam
# 3          Ross Taylor
# 4  Francois du Plessis
# 5      Kane Williamson
# 6          Aaron Finch
# 7         David Warner
# 8      Quinton de Kock
# 9       Jonny Bairstow
# None
#       Team/player
# 0     Pat Cummins
# 1    Stuart Broad
# 2     Neil Wagner
# 3     Tim Southee
# 4    Jason Holder
# 5   Kagiso Rabada
# 6  Mitchell Starc
# 7  James Anderson
# 8  Jasprit Bumrah
# 9     Trent Boult
# None
